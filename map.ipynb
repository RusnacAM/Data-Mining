# %%
# Sources: https://datascience.quantecon.org/tools/maps.html, https://stackoverflow.com/questions/72249181/how-to-insert-points-in-a-map
import pandas as pd
import folium as folium
import random

# %%
df = pd.read_csv("C:\\Users\\Adrian\\Documents\\Aarhus University\\Data Mining\\Gowalla Data\\Gowalla_totalCheckins.txt", sep = "\t", header = None)
# read csv is still using local file path.
headers = ["user_id", "checkin_time", "latitude", "longitude", "location_id"]
df.columns = headers
print(df.head())
# Out:
#    user_id          checkin_time   latitude  longitude  location_id
# 0        0  2010-10-19T23:55:27Z  30.235909 -97.795140        22847
# 1        0  2010-10-18T22:17:43Z  30.269103 -97.749395       420315
# 2        0  2010-10-17T23:42:03Z  30.255731 -97.763386       316637
# 3        0  2010-10-17T19:26:05Z  30.263418 -97.757597        16516
# 4        0  2010-10-16T18:50:42Z  30.274292 -97.740523      5535878

# %%
# Creating the map
m = folium.Map(location=[20,0], tiles="OpenStreetMap", zoom_start=2)

# %%
random.seed(1)
mylist = list(range(0, len(df)))
randomlist = random.sample(mylist, k=1000) # k can be set higher if you want more points

# %%
for i in randomlist:
    folium.Marker(
      location=[df.iloc[i]['latitude'], df.iloc[i]['longitude']],
      popup=df.iloc[i]['user_id'],
   ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_611b776588bb140f941420b39c32295a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_611b776588bb140f941420b39c32295a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_611b776588bb140f941420b39c32295a = L.map(
#                 &quot;map_611b776588bb140f941420b39c32295a&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3bd6efb0b484e9197141f33497cb03e8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3bd6efb0b484e9197141f33497cb03e8.addTo(map_611b776588bb140f941420b39c32295a);
#
#
#             var marker_029dde17d682192b6d71039ea5902d28 = L.marker(
#                 [35.3891286859, -97.5198948383],
#                 {
# }
#             ).addTo(map_611b776588bb140f941420b39c32295a);
#
#
#         var popup_8f9647e7ade53f9448eaec850e651630 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_123c8d3527fc4af67c3a5eeb0aeab1f8 = $(`&lt;div id=&quot;html_123c8d3527fc4af67c3a5eeb0aeab1f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5184&lt;/div&gt;`)[0];
#                 popup_8f9647e7ade53f9448eaec850e651630.setContent(html_123c8d3527fc4af67c3a5eeb0aeab1f8);
#
#
#
#         marker_029dde17d682192b6d71039ea5902d28.bindPopup(popup_8f9647e7ade53f9448eaec850e651630)
#         ;
#
#
#
#
#             var marker_0c6d183e35e5b19cdb7de14a6db1aaa3 = L.marker(
#                 [57.7780565734, 14.1743248688],
#                 {
# }
#             ).addTo(map_611b776588bb140f941420b39c32295a);
#
#
#         var popup_fa7454184b72478cd3db64c178626234 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0d9330b6edb32ce443db52eb0f3dbb3b = $(`&lt;div id=&quot;html_0d9330b6edb32ce443db52eb0f3dbb3b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;106123&lt;/div&gt;`)[0];
#                 popup_fa7454184b72478cd3db64c178626234.setContent(html_0d9330b6edb32ce443db52eb0f3dbb3b);
#
#
#
#         marker_0c6d183e35e5b19cdb7de14a6db1aaa3.bindPopup(popup_fa7454184b72478cd3db64c178626234)
#         ;
#
#
#
#
#             var marker_d3fd7224f96173aeca53e206aaa546cf = L.marker(
#                 [46.8646433283, -114.0035639803],
#                 {
# }
#             ).addTo(map_611b776588bb140f941420b39c32295a);
#
#
#         var popup_09472ee5b795db2262af32d91cfdfb38 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8bf7fbf42c064327233c01b1fc09591b = $(`&lt;div id=&quot;html_8bf7fbf42c064327233c01b1fc09591b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;190179&lt;/div&gt;`)[0];
#                 popup_09472ee5b795db2262af32d91cfdfb38.setContent(html_8bf7fbf42c064327233c01b1fc09591b);
#
#
#
#         marker_d3fd7224f96173aeca53e206aaa546cf.bindPopup(popup_09472ee5b795db2262af32d91cfdfb38)
#         ;
#
#
#
#
#             var marker_aa55faca5e676259207ff4e87fe7ed09 = L.marker(
#                 [34.1125151833, -117.5265562534],
#                 {
# }
#             ).addTo(map_611b776588bb140f941420b39c32295a);
#
#
#         var popup_f2cb1d15c3c4b7f632ffa43114f2d857 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d8a6abc05e4a25e10ffddc9565c40407 = $(`&lt;div id=&quot;html_d8a6abc05e4a25e10ffddc9565c40407&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2088&lt;/div&gt;`)[0];
#                 popup_f2cb1d15c3c4b7f632ffa43114f2d857.setContent(html_d8a6abc05e4a25e10ffddc9565c40407);
#
#
#
#         marker_aa55faca5e676259207ff4e87fe7ed09.bindPopup(popup_f2cb1d15c3c4b7f632ffa43114f2d857)
#         ;
#
#
#
#
#             var marker_054cbe99f2776591ab87a4f9a0dca707 = L.marker(
#                 [40.42891535, -3.7019802333],
#                 {
# }
#             ).addTo(map_611b776588bb140f941420b39c32295a);
#
#
#         var popup_233f4bbcd695a1bfecb885efdfee6938 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d53a03a1ca11de0238abb7438e8c2796 = $(`&lt;div id=&quot;html_d53a03a1ca11de0238abb7438e8c2796&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;18992&lt;/div&gt;`)[0];
#                 popup_233f4bbcd695a1bfecb885efdfee6938.setContent(html_d53a03a1ca11de0238abb7438e8c2796);
#
#
#
#         marker_054cbe99f2
